# %% [markdown]
# # Tweet Scraping, Sentiment Analysis, Topic Modeling
# - code was borrowed and adapted from https://towardsdatascience.com/topic-modelling-in-python-with-nltk-and-gensim-4ef03213cd21

# %%
import numpy as np
import pandas as pd

# %%
import tweepy
consumer_key = "duJukP6oV4SlzSpJtOxj3OzKt"
consumer_secret = "wc7pfQdTpd0gwFzKYrtLtvAZcAB36lQvGGEfv7wCRcEtn86RNC"
access_token = "1142540378614059010-0TIQEKCvfsx39VQ8T8tKKeC61AQv2t"
access_token_secret = "65EykoR8QLFvgpD4etFmrvQpTKS2oLkoHMU2iKLK6luNi"

# %%
# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth)

# %% [markdown]
# __Getting Tweets from my timeline into the notebook__

# %%
# Using the API object to get tweets from your timeline, and storing it in a variable called public_tweets
public_tweets = api.home_timeline()
# foreach through all tweets pulled
for tweet in public_tweets:
   # printing the text stored inside the tweet object
   print (tweet.text)
# Out:
# 🚨 BREAKING NEWS 🚨 – the U.S. economy has added 224,000 jobs to the payroll, the highest gain since January! https://t.co/PJJujZw1fc
# RT @supertalk: It’s Friday and we’re talking the fake meat burgers with @CommAndyGipson 🍔 on @thejtshow! What’s it all about and what does…
# Can a plant identify as “meat?”  Join me on @thejtshow at 11 today to discuss the lawsuit by Illinois vegans agains… https://t.co/xgiCXpqFWX
# RT @SenateGOP: BREAKING: The Jobs Report is in – American job creators added 224,000 jobs in June and wages are up. The economy is booming.…
# RT @SenateGOP: 🚨 BREAKING 🚨
#
# @CNBC: "Strong job growth is back: Payrolls jump in June well above expectations"
#
# https://t.co/2aACVQkUim
# There has been a huge amount of misinformation and frankly false claims by powerful out of state interests about Mi… https://t.co/o6u8eIlaCm
# President Trump reminds us once again that it is the people that Make America Great. Thank you Mr. President for yo… https://t.co/NVsIrI4m7z
# Even youths grow tired and weary, and young men stumble and fall; but those who hope in the Lord will renew their s… https://t.co/2EmZsf1R6b
# Elee and the girls loved the Ridgeland balloon glow! Lots of people out to celebrate the 4th! https://t.co/9qO004mCev
# Enjoyed speaking at the famous Jacinto Courthouse Fourth of July Festival, with some of my best supporters!  Thank… https://t.co/TU2LAcGQKR
# The liberals lost their minds about our President holding a patriotic celebration in our nation’s capitol. And it w… https://t.co/eyCDWk3yxK
# Amazing time talking with people at Olive Branch’s Celebrate Your Independence Festival! Rain won’t stop these folk… https://t.co/LecZUxvFQv
# Nothing says 4th of July like rock climbing, face paint, and fireworks! Elee and the girls are at the Clinton Extra… https://t.co/dqD5MZ48Vk
# Capping the Fourth off with Senator @mcmahanms and stumping in Jacinto. Happy Independence Day! 🇺🇸🇺🇸🇺🇸 https://t.co/S3YXazhzqn
# Great time celebrating our nation’s independence with folks at the All-America City Family Picnic in Tupelo! Even… https://t.co/SMwGuaMxeU
# Wishing you and your loved ones a happy, safe Fourth of July! And please join me in thanking our law enforcement wh… https://t.co/zhdmsX3jM9
# Workforce is EVERYTHING in economic development. Proud to share our achievements with @WorkingNation at… https://t.co/K4Z6KPISEG
# Mississippi-based coffee roaster Southern Coffee Services is expanding its operations in Lexington. The project is… https://t.co/oQIMqbHWSj
# Also today during lunch, I got to listen in on a panel with @IvankaTrump She was great and is doing an amazing job… https://t.co/OowSFeMnN2
# What an incredible first day at the #MIGlobal conference. Had a chance to spend time with @MickMulvaneyOMB… https://t.co/p8VaPBeWaE
# Proud to be telling the story of opportunity zones in Mississippi at #MIGlobal Conference. @realDonaldTrump is righ… https://t.co/qGPwNM3sbZ
# Thankful for the chance to join @aronbetru, @BrentJMcIntosh, @CIMGroupLP co-founder Richard Ressler, &amp; Investor Man… https://t.co/EcjawiPqX0
# Deeply saddened by this yesterday. Antisemitism has consequences. People of all faiths should not have to live in f… https://t.co/Kk81yzcYuY
# The crowd is beginning to gather in Veterans Memorial Stadium for the Unite Mississippi “Night of Unity”.… https://t.co/Od6TjFOTcX
# So proud of my friend @BrianKempGA for his efforts to protect the unborn in the great state of Georgia. @GOP govern… https://t.co/K9dzBQeRty
# Good work by @GovBillLee. The children of Tennessee will be all the better for his hard work in bringing them ESAs. https://t.co/cOfCft5ltD
# Great job by @SenHydeSmith. @SecAzar is spot on. By expanding technology through rural broadband and removing burde… https://t.co/xoAMw5bouA
# We cut the ribbon on the new Phillips Health Center in Moorhead, MS, this morning. It will provide health care to c… https://t.co/3CPixMHdOW
# Proud of so many members of my staff who have left to pursue great opportunities. They work tirelessly to make Miss… https://t.co/7yAOK0CFmo
# I signed Executive Order 1438 this morning creating the Mississippi Rural Health Care Task Force that will study th… https://t.co/lhqoi37BaG
# Today we recognize the incredible efforts made to fight malaria across the globe. Thank you @USAID and @PMIgov for… https://t.co/SeDGevjK8E
# Currently getting a briefing at @MSEMA on the severe weather that has pushed through Mississippi today. 316 power o… https://t.co/EQVFyPBCjC

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
class SeleniumClient(object):
    def __init__(self):
        #Initialization method. 
        self.chrome_options = webdriver.ChromeOptions()
        self.chrome_options.add_argument('--headless')
        self.chrome_options.add_argument('--no-sandbox')
        self.chrome_options.add_argument('--disable-setuid-sandbox')

        # you need to provide the path of chromdriver in your system
        self.browser = webdriver.Chrome('C:\webdrivers\chromedriver.exe', options=self.chrome_options)
       
        self.base_url = 'https://twitter.com/search?q='

    def get_tweets(self, query):
        ''' 
        Function to fetch tweets. 
        '''
        try: 
            self.browser.get(self.base_url+query)
            time.sleep(2)

            body = self.browser.find_element_by_tag_name('body')

            for _ in range(3000):
                body.send_keys(Keys.PAGE_DOWN)
                time.sleep(0.3)

            timeline = self.browser.find_element_by_id('timeline')
            tweet_nodes = timeline.find_elements_by_css_selector('.tweet-text')

            return pd.DataFrame({'tweets': [tweet_node.text for tweet_node in tweet_nodes]})

        except: 
            print("Selenium - An error occured while fetching tweets.")

# %%
selenium_client = SeleniumClient()

tweets_df = selenium_client.get_tweets('AI and Deep Learning')
# Out:
# Selenium - An error occured while fetching tweets.

# %% [markdown]
# # Modified this class to retrieve timelines rather than references to people's twitter handle
# - https://towardsdatascience.com/selenium-tweepy-to-scrap-tweets-from-tweeter-and-analysing-sentiments-1804db3478ac

# %%
import tweepy
from tweepy import OAuthHandler
name = "PhilBryantMS"
name2 = "BraceyHarris"
class TwitterClient(object): 
    
    def __init__(self):
       # Access Credentials 
        consumer_key = "duJukP6oV4SlzSpJtOxj3OzKt"
        consumer_secret = "wc7pfQdTpd0gwFzKYrtLtvAZcAB36lQvGGEfv7wCRcEtn86RNC"
        access_token = "1142540378614059010-0TIQEKCvfsx39VQ8T8tKKeC61AQv2t"
        access_token_secret = "65EykoR8QLFvgpD4etFmrvQpTKS2oLkoHMU2iKLK6luNi"
        try: 
            # OAuthHandler object 
            auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            auth.set_access_token(access_token, access_token_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
            
        except tweepy.TweepError as e:
            print(f"Error: Twitter Authentication Failed - \n{str(e)}") 

   # Function to fetch tweets
    def get_tweets(self, query, maxTweets = 7000): 
        # empty list to store parsed tweets 
        tweets = [] 
        sinceId = None
        max_id = -1
        tweetCount = 0
        tweetsPerQry = 1000
        
        while tweetCount < maxTweets:
            try:
                if (max_id <= 0):
                    if (not sinceId):
                        new_tweets = self.api.user_timeline(id=name, count=tweetsPerQry)
                    else:
                        new_tweets = self.api.user_timeline(id=name, count=tweetsPerQry,
                                                since_id=sinceId)
                else:
                    if (not sinceId):
                        new_tweets = self.api.user_timeline(id=name, count=tweetsPerQry,
                                                max_id=str(max_id - 1))
                    else:
                        new_tweets = self.api.user_timeline(id=name, count=tweetsPerQry,
                                                max_id=str(max_id - 1),
                                                since_id=sinceId)
                if not new_tweets:
                    print("No more tweets found")
                    break
                    
                for tweet in new_tweets:
                    parsed_tweet = {} 
                    parsed_tweet['tweets'] = tweet.text 

                    # appending parsed tweet to tweets list 
                    if tweet.retweet_count > 0: 
                        # if tweet has retweets, ensure that it is appended only once 
                        if parsed_tweet not in tweets: 
                            tweets.append(parsed_tweet) 
                    else: 
                        tweets.append(parsed_tweet) 
                        
                tweetCount += len(new_tweets)
                print("Downloaded {0} tweets".format(tweetCount))
                max_id = new_tweets[-1].id

            except tweepy.TweepError as e:
                print("Tweepy error : " + str(e))
                break
        
        return pd.DataFrame(tweets)

# %% [markdown]
# __Instantiate the class, then create a df__

# %%
client = TwitterClient()

tweets_df = client.get_tweets("PhilBryantMS")
# Out:
# Downloaded 200 tweets
# Downloaded 400 tweets
# Downloaded 600 tweets
# Downloaded 800 tweets
# Downloaded 1000 tweets
# Downloaded 1200 tweets
# Downloaded 1400 tweets
# Downloaded 1600 tweets
# Downloaded 1800 tweets
# Downloaded 2000 tweets
# Downloaded 2200 tweets
# Downloaded 2400 tweets
# Downloaded 2599 tweets
# Downloaded 2799 tweets
# Downloaded 2998 tweets
# Downloaded 3198 tweets
# Downloaded 3213 tweets
# No more tweets found

# %%
tweets_df
# Out:
#                                                  tweets
# 0     President Trump reminds us once again that it ...
# 1     I’m for Tate.                                 ...
# 2     Women were very prominent in founding of natio...
# 3     Appreciate our entire Congressional Delegation...
# 4     Thank you @CongPalazzo. I am sure @SecretaryRo...
# 5     Unbelievable success these past 7 years in ter...
# 6     Great conversation this morning with @Secretar...
# 7     Ray you’ve been gone awhile but trust me our s...
# 8     Well said Commissioner. We will stand with you...
# 9     Great to hear @US_EDA @CommerceGov awarded Cit...
# 10    RT @OleMissAirSpace: Yes! #Mississippi is taki...
# 11    If I remember correctly Sheriff Woody was smar...
# 12    I believe that we have the capabilities to att...
# 13    Today I announced an economic development Spac...
# 14    RT @MaryPerezSH: Patrick Scheuermann named new...
# 15    Strange how some Metro media outlets report th...
# 16    Very proud of these National Champions.  They ...
# 17    I have been to the border and have visited wit...
# 18    When you are ready to run for Governor of Arka...
# 19    RT @SenHydeSmith: This is long-awaited good ne...
# 20    I appreciate the hard work and diligence by @S...
# 21    Republicans have cut taxes over 50 times in th...
# 22    Lt. Governor @tatereeves has worked hard for t...
# 23    We must do all we can to advance marine educat...
# 24    Every year @usedgov recognizes outstanding hig...
# 25    Proud to welcome @KRONE_NA to Olive Branch. We...
# 26    RT @MDESMS: Don’t forget to dress for success ...
# 27    RT @MichaelWatsonMS: We just released a new ad...
# 28    Proud to support @MichaelWatsonMS for Secretar...
# 29    My grandchildren Henry and Phillip enjoy a mor...
# ...                                                 ...
# 3182  Also, good luck to the EMCC football team this...
# 3183  Congrats to the Alcorn State football team for...
# 3184  Great to be at the Cspire ribbon cutting today...
# 3185  Today we are in the Golden Triangle area makin...
# 3186  RT @UMMCTelehealth: #Mississippi Governor @Phi...
# 3187  RT @CSpire: .@PhilBryantMS : Combating poverty...
# 3188  It's great to be in the MS Delta w/ FCC Commis...
# 3189  It's an honor to be with some wonderful compan...
# 3190  RT @FCC: Telehealth is truly saving lives in M...
# 3191  I'm happy to be in Tupelo today on my Mississi...
# 3192  #MSWorks A great day for Oxford as mortgage te...
# 3193  It's great to be speaking at the MBCC State Br...
# 3194  I have long opposed Common Core in Mississippi...
# 3195  I'll be introducing the Ole Miss season in rev...
# 3196  Good luck to both Ole Miss and MSU today in th...
# 3197  Happy Thanksgiving from Deborah and I! We hope...
# 3198  As many of us around the state get set to trav...
# 3199  Happy to present Mission Mississippi with a $3...
# 3200  Getting ready to unveil the check for Mission ...
# 3201  Good luck to our Mississippi deer hunters this...
# 3202  I have named all the members of the task force...
# 3203  For more information on Jobs for America's Gra...
# 3204  Today I accepted the position of chair-elect f...
# 3205  It's great to be speaking today at MCEDA/Madis...
# 3206  I released my FY 2016 executive budget recomme...
# 3207  We just completed the ribbon cutting at Seafoo...
# 3208  Happy to announce 100 new jobs coming to Laude...
# 3209  It's great to be speaking at the Mississippian...
# 3210  Today we remember &amp; say thanks to all thos...
# 3211  I've set a new date in the Scott County School...
#
# [3212 rows x 1 columns]

# %% [markdown]
# __Try to remove @__

# %%
import re
def remove_pattern(text, pattern_regex):
    r = re.findall(pattern_regex, text)
    for i in r:
        text = re.sub(i, '', text)
    
    return text
# We are keeping cleaned tweets in a new column called 'tidy_tweets'
tweets_df['tidy_tweets'] = np.vectorize(remove_pattern)(tweets_df['tweets'], "@[\w]*: | *RT*")

# %% [markdown]
# __Remove links__

# %%
cleaned_tweets = []

for index, row in tweets_df.iterrows():
    # Here we are filtering out all the words that contains link
    words_without_links = [word for word in row.tidy_tweets.split()        if 'http' not in word]
    cleaned_tweets.append(' '.join(words_without_links))

tweets_df['tidy_tweets'] = cleaned_tweets

# %% [markdown]
# __Drop duplicate rows__

# %%
tweets_df.drop_duplicates(subset=['tidy_tweets'], keep=False)
# Out:
#                                                  tweets  \
# 0     President Trump reminds us once again that it ...
# 1     I’m for Tate.                                 ...
# 2     Women were very prominent in founding of natio...
# 3     Appreciate our entire Congressional Delegation...
# 4     Thank you @CongPalazzo. I am sure @SecretaryRo...
# 5     Unbelievable success these past 7 years in ter...
# 6     Great conversation this morning with @Secretar...
# 7     Ray you’ve been gone awhile but trust me our s...
# 8     Well said Commissioner. We will stand with you...
# 9     Great to hear @US_EDA @CommerceGov awarded Cit...
# 10    RT @OleMissAirSpace: Yes! #Mississippi is taki...
# 11    If I remember correctly Sheriff Woody was smar...
# 12    I believe that we have the capabilities to att...
# 13    Today I announced an economic development Spac...
# 14    RT @MaryPerezSH: Patrick Scheuermann named new...
# 15    Strange how some Metro media outlets report th...
# 16    Very proud of these National Champions.  They ...
# 17    I have been to the border and have visited wit...
# 18    When you are ready to run for Governor of Arka...
# 19    RT @SenHydeSmith: This is long-awaited good ne...
# 20    I appreciate the hard work and diligence by @S...
# 21    Republicans have cut taxes over 50 times in th...
# 22    Lt. Governor @tatereeves has worked hard for t...
# 23    We must do all we can to advance marine educat...
# 24    Every year @usedgov recognizes outstanding hig...
# 25    Proud to welcome @KRONE_NA to Olive Branch. We...
# 26    RT @MDESMS: Don’t forget to dress for success ...
# 27    RT @MichaelWatsonMS: We just released a new ad...
# 28    Proud to support @MichaelWatsonMS for Secretar...
# 29    My grandchildren Henry and Phillip enjoy a mor...
# ...                                                 ...
# 3182  Also, good luck to the EMCC football team this...
# 3183  Congrats to the Alcorn State football team for...
# 3184  Great to be at the Cspire ribbon cutting today...
# 3185  Today we are in the Golden Triangle area makin...
# 3186  RT @UMMCTelehealth: #Mississippi Governor @Phi...
# 3187  RT @CSpire: .@PhilBryantMS : Combating poverty...
# 3188  It's great to be in the MS Delta w/ FCC Commis...
# 3189  It's an honor to be with some wonderful compan...
# 3190  RT @FCC: Telehealth is truly saving lives in M...
# 3191  I'm happy to be in Tupelo today on my Mississi...
# 3192  #MSWorks A great day for Oxford as mortgage te...
# 3193  It's great to be speaking at the MBCC State Br...
# 3194  I have long opposed Common Core in Mississippi...
# 3195  I'll be introducing the Ole Miss season in rev...
# 3196  Good luck to both Ole Miss and MSU today in th...
# 3197  Happy Thanksgiving from Deborah and I! We hope...
# 3198  As many of us around the state get set to trav...
# 3199  Happy to present Mission Mississippi with a $3...
# 3200  Getting ready to unveil the check for Mission ...
# 3201  Good luck to our Mississippi deer hunters this...
# 3202  I have named all the members of the task force...
# 3208  Happy to announce 100 new jobs coming to Laude...
# 3209  It's great to be speaking at the Mississippian...
# 3210  Today we remember &amp; say thanks to all thos...
# 3211  I've set a new date in the Scott County School...
#
# [3210 rows x 2 columns]

# %% [markdown]
# __Remove numbers, punctuation, and special characters__

# %%
tweets_df['absolute_tidy_tweets'] = tweets_df['tidy_tweets'].str.replace("[^a-zA-Z# ]", "")

# %% [markdown]
# __Remove stop words__

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords_set = set(stopwords.words("english"))
cleaned_tweets = []

for index, row in tweets_df.iterrows():
    
    # filerting out all the stopwords 
    words_without_stopwords = [word for word in row.absolute_tidy_tweets.split() if not word in stopwords_set]
    
    # finally creating tweets list of tuples containing stopwords(list) and sentimentType 
    cleaned_tweets.append(' '.join(words_without_stopwords))

tweets_df['absolute_tidy_tweets'] = cleaned_tweets
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Sam
# [nltk_data]     Cannon\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# __tokenization and lemmatization__

# %%
from nltk.stem import WordNetLemmatizer
# Tokenization
tokenized_tweet = tweets_df['absolute_tidy_tweets'].apply(lambda x: x.split())
# Finding Lemma for each word
word_lemmatizer = WordNetLemmatizer()
tokenized_tweet = tokenized_tweet.apply(lambda x: [word_lemmatizer.lemmatize(i) for i in x])
#joining words into sentences (from where they came from)
for i, tokens in enumerate(tokenized_tweet):
    tokenized_tweet[i] = ' '.join(tokens)

tweets_df['absolute_tidy_tweets'] = tokenized_tweet

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# BOW features
bow_word_vectorizer = CountVectorizer(max_df=0.90, min_df=2, stop_words='english')
# bag-of-words feature matrix
bow_word_feature = bow_word_vectorizer.fit_transform(tweets_df['absolute_tidy_tweets'])

# TF-IDF features
tfidf_word_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, stop_words='english')
# TF-IDF feature matrix
tfidf_word_feature = tfidf_word_vectorizer.fit_transform(tweets_df['absolute_tidy_tweets'])

# %%
tweets_df
# Out:
#                                                  tweets  \
# 0     President Trump reminds us once again that it ...
# 1     I’m for Tate.                                 ...
# 2     Women were very prominent in founding of natio...
# 3     Appreciate our entire Congressional Delegation...
# 4     Thank you @CongPalazzo. I am sure @SecretaryRo...
# 5     Unbelievable success these past 7 years in ter...
# 6     Great conversation this morning with @Secretar...
# 7     Ray you’ve been gone awhile but trust me our s...
# 8     Well said Commissioner. We will stand with you...
# 9     Great to hear @US_EDA @CommerceGov awarded Cit...
# 10    RT @OleMissAirSpace: Yes! #Mississippi is taki...
# 11    If I remember correctly Sheriff Woody was smar...
# 12    I believe that we have the capabilities to att...
# 13    Today I announced an economic development Spac...
# 14    RT @MaryPerezSH: Patrick Scheuermann named new...
# 15    Strange how some Metro media outlets report th...
# 16    Very proud of these National Champions.  They ...
# 17    I have been to the border and have visited wit...
# 18    When you are ready to run for Governor of Arka...
# 19    RT @SenHydeSmith: This is long-awaited good ne...
# 20    I appreciate the hard work and diligence by @S...
# 21    Republicans have cut taxes over 50 times in th...
# 22    Lt. Governor @tatereeves has worked hard for t...
# 23    We must do all we can to advance marine educat...
# 24    Every year @usedgov recognizes outstanding hig...
# 25    Proud to welcome @KRONE_NA to Olive Branch. We...
# 3186  #Mississippi Governor PhilBryantMS meet w Anni...
# 3187  PhilBryantMS Combating poverty Mississippi tec...
# 3188  Its great MS Delta w FCC Commissioner Mignon C...
# 3189  Its honor wonderful company today Governors Aw...
# 3190  Telehealth truly saving life Mississippi Thank...
# 3191  Im happy Tupelo today Mississippi Works tour e...
# 3192  #MSWorks A great day Oxford mortgage tech firm...
# 3193  Its great speaking MBCC State Broadband Summit...
# 3194  I long opposed Common Core Mississippi I thank...
# 3195  Ill introducing Ole Miss season review pm CBS ...
# 3196  Good luck Ole Miss MSU today #EggBowl Two wond...
# 3197  Happy Thanksgiving Deborah I We hope day full ...
# 3198  As many u around state get set travel holiday ...
# 3199  Happy present Mission Mississippi check Get Up...
# 3200  Getting ready unveil check Mission MS proceeds...
# 3201  Good luck Mississippi deer hunter weekend Be s...
# 3202  I named member task force oversee contract rev...
# 3203  For information Jobs Americas Graduates detail...
# 3204  Today I accepted position chairelect Jobs Amer...
# 3205  Its great speaking today MCEDAMadison County B...
# 3206  I released FY executive budget recommendation ...
# 3207  We completed ribbon cutting Seafoodevolution C...
# 3208  Happy announce new job coming Lauderdale Co ne...
# 3209  Its great speaking Mississippians Economic Pro...
# 3210  Today remember amp say thanks served amp sacri...
# 3211  Ive set new date Scott County School Board spe...
#
# [3212 rows x 3 columns]

# %% [markdown]
# # Sentiment
# - These functions reveal sentiment for text, but we must use different code for columnwise operations, this code is in the cells below the functions

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
def fetch_sentiment_using_SIA(text):
    sid = SentimentIntensityAnalyzer()
    polarity_scores = sid.polarity_scores(text)
    if polarity_scores['neg'] > polarity_scores['pos']:
        return 'negative'
    else:
        return 'positive'

def fetch_sentiment_using_textblob(text):
    analysis = TextBlob(text)
    # set sentiment 
    if analysis.sentiment.polarity >= 0:
        return 'positive'
    else: 
        return 'negative'

# %% [markdown]
# __applying sentiment analysis columnwise__

# %%
tweets_df[['polarity','subjectivity']] = tweets_df['tweets'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))

# %%
tweets_df
# Out:
#                                                  tweets  \
# 0     President Trump reminds us once again that it ...
# 1     I’m for Tate.                                 ...
# 2     Women were very prominent in founding of natio...
# 3     Appreciate our entire Congressional Delegation...
# 4     Thank you @CongPalazzo. I am sure @SecretaryRo...
# 5     Unbelievable success these past 7 years in ter...
# 6     Great conversation this morning with @Secretar...
# 7     Ray you’ve been gone awhile but trust me our s...
# 8     Well said Commissioner. We will stand with you...
# 9     Great to hear @US_EDA @CommerceGov awarded Cit...
# 10    RT @OleMissAirSpace: Yes! #Mississippi is taki...
# 11    If I remember correctly Sheriff Woody was smar...
# 12    I believe that we have the capabilities to att...
# 13    Today I announced an economic development Spac...
# 14    RT @MaryPerezSH: Patrick Scheuermann named new...
# 15    Strange how some Metro media outlets report th...
# 16    Very proud of these National Champions.  They ...
# 17    I have been to the border and have visited wit...
# 18    When you are ready to run for Governor of Arka...
# 19    RT @SenHydeSmith: This is long-awaited good ne...
# 20    I appreciate the hard work and diligence by @S...
# 25    Proud welcome KONENA Olive Branch We German fo...  0.345833
# 26    Dont forget dress success attend MississippieE...  0.500000
# 27    We released new ad featuring good friend PhilB...  0.545455
# 28    Proud support MichaelWatsonMS Secretary State ...  0.150000
# 29    My grandchild Henry Phillip enjoy morning Gove...  0.400000
# ...                                                 ...       ...
# 3182  Also good luck EMCC football team weekend bid ...  0.875000
# 3183  Congrats Alcorn State football team great seas...  0.333333
# 3184  Great Cspire ribbon cutting today new data cen...  0.059091
# 3185  Today Golden Triangle area making stop Mississ...  0.250000
# 3186  #Mississippi Governor PhilBryantMS meet w Anni...  0.200000
# 3187  PhilBryantMS Combating poverty Mississippi tec...  0.000000
# 3188  Its great MS Delta w FCC Commissioner Mignon C...  0.550000
# 3189  Its honor wonderful company today Governors Aw...  1.000000
# 3190  Telehealth truly saving life Mississippi Thank...  0.600000
# 3191  Im happy Tupelo today Mississippi Works tour e...  0.500000
# 3192  #MSWorks A great day Oxford mortgage tech firm...  0.256818
# 3193  Its great speaking MBCC State Broadband Summit...  0.900000
# 3194  I long opposed Common Core Mississippi I thank... -0.175000
# 3195  Ill introducing Ole Miss season review pm CBS ...  0.000000
# 3196  Good luck Ole Miss MSU today #EggBowl Two wond...  0.650000
# 3197  Happy Thanksgiving Deborah I We hope day full ...  0.366667
# 3198  As many u around state get set travel holiday ...  0.108889
# 3199  Happy present Mission Mississippi check Get Up...  0.385714
# 3200  Getting ready unveil check Mission MS proceeds...  0.278571
# 3201  Good luck Mississippi deer hunter weekend Be s...  0.375000
# 3202  I named member task force oversee contract rev...  0.000000
# 3203  For information Jobs Americas Graduates detail...  0.500000
# 3204  Today I accepted position chairelect Jobs Amer...  1.000000
# 3205  Its great speaking today MCEDAMadison County B...  0.800000
# 3206  I released FY executive budget recommendation ...  0.350000
# 3207  We completed ribbon cutting Seafoodevolution C...  0.125000
# 3208  Happy announce new job coming Lauderdale Co ne...  0.312121
# 3209  Its great speaking Mississippians Economic Pro...  0.500000
# 3210  Today remember amp say thanks served amp sacri...  0.500000
# 3211  Ive set new date Scott County School Board spe...  0.246753
#
#       subjectivity
# 0         0.750000
# 1         0.000000
# 2         1.000000
# 3         0.762500
# 4         0.730159
# 5         0.416667
# 6         0.645833
# 7         0.470000
# 8         0.000000
# 9         0.750000
# 10        0.900000
# 11        1.000000
# 12        0.375000
# 13        0.200000
# 14        0.227273
# 15        0.150000
# 16        0.533333
# 17        0.950000
# 18        0.296296
# 19        0.616667
# 20        0.770833
# 21        0.066667
# 22        0.541667
# 23        0.400000
# 24        0.707500
# 25        0.487500
# 26        0.450000
# 27        0.601515
# 28        0.750000
# 29        0.500000
# ...            ...
# 3182      0.600000
# 3183      0.583333
# 3184      0.551136
# 3185      0.350000
# 3186      0.150000
# 3187      0.250000
# 3188      0.375000
# 3189      1.000000
# 3190      0.475000
# 3191      0.600000
# 3192      0.534848
# 3193      0.875000
# 3194      0.450000
# 3195      0.000000
# 3196      0.800000
# 3197      0.600000
# 3198      0.357778
# 3199      0.523810
# 3200      0.535714
# 3201      0.325000
# 3202      0.000000
# 3203      0.500000
# 3204      1.000000
# 3205      0.750000
# 3206      0.550000
# 3207      0.950000
# 3208      0.484848
# 3209      0.475000
# 3210      0.475000
# 3211      0.512987
#
# [3212 rows x 5 columns]

# %%
target_variable = tweets_df['polarity'].apply(lambda x: 0 if x < 0 else 1 )

# %%
target_variable
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# 5       0
# 6       1
# 7       1
# 8       1
# 9       1
# 10      1
# 11      1
# 12      0
# 13      1
# 14      1
# 15      0
# 16      1
# 17      1
# 18      1
# 19      1
# 20      1
# 21      1
# 22      0
# 23      1
# 24      1
# 25      1
# 26      1
# 27      1
# 28      1
# 29      1
#        ..
# 3182    1
# 3183    1
# 3184    1
# 3185    1
# 3186    1
# 3187    1
# 3188    1
# 3189    1
# 3190    1
# 3191    1
# 3192    1
# 3193    1
# 3194    0
# 3195    1
# 3196    1
# 3197    1
# 3198    1
# 3199    1
# 3200    1
# 3201    1
# 3202    1
# 3203    1
# 3204    1
# 3205    1
# 3206    1
# 3207    1
# 3208    1
# 3209    1
# 3210    1
# 3211    1
# Name: polarity, Length: 3212, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(20, 10))
sns.distplot(tweets_df['polarity'], bins = 8)

# %%
neg_tweets = tweets_df[tweets_df['polarity'] < 0]

# %%
neg_tweets
# Out:
#                                                 tweets  \
# 5    Unbelievable success these past 7 years in ter...
# 12   I believe that we have the capabilities to att...
# 15   Strange how some Metro media outlets report th...
# 22   Lt. Governor @tatereeves has worked hard for t...
# 38   Thanks for joining Mississippi in leading in c...
# 58   Men in Black do it again. #HailState https://t...
# 67   Because of the hard work &amp; determination o...
# 82   ecosystem impacts due to the opening of the Sp...
# 88   Terribly sad day in Kemper County. @FirstLady_...
# 154  Nursing is the nation’s largest healthcare pro...
# 161  Thanks to @amazon for recognizing Mississippi ...
# 209  This is as bad as it gets. The attack on State...
# 212  Horrible attack against Christians this Easter...
# 221  We are saddened by every loss during this diff...
# 254  I participated today in the Over the Edge even...
# 258  Additionally, the @MECStateChamber financial d...
# 269  We must never forget the victims of violent cr...
# 358  I sure would hate to be a Democrat running for...
# 371  So @SenWarren will shut out the Mississippi me...
# 380  Congratulations to @OleMissRebels basketball c...
# 387  I'll be on the @thejtshow on SuperTalk Mississ...
# 389  It was a long, difficult day for everyone in t...
# 392  Another round of severe weather is expected to...
# 394  This week the Mississippi Republican Women hon...
# 403  Whether it’s through @SWIB_MS, the Mississippi...
# 405  Mississippi has led the nation in criminal jus...
# 419  Last year nearly $4 billion was spent on child...
# 445  Please remain vigilant over the next few days ...
# 448  Rainfall totals have been very heavy over the ...
# 456  Please be weather aware this week as heavy rai...
# ..                                                 ...
# 692  Shut it down, Mr. President. The MAGA Nation w...
# 693  Sad, but expected, the mainstream media would ...
# 695  Serious flooding in south Mississippi is possi...
# 701  There is potential for severe weather in Missi...
# 743  I spoke at the first Mississippi Summit on Cri...
# 753  Even in this season of joy, we must remember t...
# 757  The cause for the tragic crash of Yankee 72 in...
# 768  Mississippi Medicaid enrollment is now at 672,...
# 806  And the media will cover that fake poll like i...
# 817  Thank you, Madam Chairman. People in Mississip...
# 832  All of this has been made possible by the stat...
# 833  Other proposed FY2020 budget items:\n\nPay rai...
# 768  Mississippi Medicaid enrollment That people si... -0.103704      0.214815
# 806   And medium cover fake poll like gospel #fakenews -0.500000      1.000000
# 817  Thank Madam Chairman People Mississippi know c... -0.500000      1.000000
# 832  All made possible state budget growing million... -0.062500      0.687500
# 833  Other proposed FY budget item Pay raise MDOC o... -0.125000      0.375000
# 849  We sorry hear loss Trooper Vincent Special pra... -0.071429      0.785714
# 857  This Veterans Day honor United States Military... -0.100000      0.100000
# 866  We forever grateful military veteran sacrifice... -0.100000      0.100000
# 876  We unveiled plaque today late Speaker Tim Ford... -0.300000      0.600000
# 877  To everyone supported campaign thank To conser... -0.125000      0.375000
# 889  Our prayer Grubbs family Magee Fire Department... -0.500000      1.000000
# 891  Democrats using dirty trick Sen CindyHyde Smit... -0.600000      0.800000
# 896  Cindy HydeSmith hit every low dirty trick book... -0.251852      0.462963
# 918  We pray victim family Evil still exists world ... -1.000000      1.000000
# 921  Thank TheJusticeDept funding million support l... -0.500000      0.500000
# 940  SenSchumer youre wrong This unconstitutional O... -0.500000      0.900000
# 944  The death littleoyalty Marie Floyd week Missis... -0.581250      0.737500
# 946  Wells Fargo bringing NeigborhoodLIFT program M... -0.027778      0.144444
# 948  This troubling disappointing see one universit... -0.600000      0.700000
# 949  Thousands adult Mississippi enough hour degree... -0.062500      0.333333
# 951  When PhilBryantMS appointed US Senate wasnt so... -0.244444      0.616667
# 954  We broke ground today theefuge Hotel Conferenc... -0.100000      0.100000
# 973  State emergency issued #Alabama #Florida #Hurr... -0.100000      0.400000
#
# [79 rows x 5 columns]

# %% [markdown]
# # Feature Extraction using TF-IDF and Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# BOW features
bow_word_vectorizer = CountVectorizer(max_df=0.90, min_df=2, stop_words='english')
# bag-of-words feature matrix
bow_word_feature = bow_word_vectorizer.fit_transform(tweets_df['absolute_tidy_tweets'])

# TF-IDF features
tfidf_word_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, stop_words='english')
# TF-IDF feature matrix
tfidf_word_feature = tfidf_word_vectorizer.fit_transform(tweets_df['absolute_tidy_tweets'])

# %% [markdown]
# # Predicting tweet sentiment using naive_bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
def naive_model(X_train, X_test, y_train, y_test):
    naive_classifier = GaussianNB()
    naive_classifier.fit(X_train.toarray(), y_train)

    # predictions over test set
    predictions = naive_classifier.predict(X_test.toarray())
    
    # calculating f1 score
    print(f'F1 Score - {f1_score(y_test, predictions)}')

# %% [markdown]
# __Use Bag or Words Feature__

# %%
X_train, X_test, y_train, y_test = train_test_split(bow_word_feature, target_variable, test_size=0.3, random_state=870)
naive_model(X_train, X_test, y_train, y_test)
# Out:
# F1 Score - 0.9469964664310954

# %% [markdown]
# __Use TF-IDF Feature__

# %%
X_train, X_test, y_train, y_test = train_test_split(tfidf_word_feature, target_variable, test_size=0.3, random_state=870)
naive_model(X_train, X_test, y_train, y_test)
# Out:
# F1 Score - 0.9469964664310954

# %% [markdown]
# It appears as though these are equally good!

# %% [markdown]
# # Wordcloud

# %% [markdown]
# https://peekaboo-vision.blogspot.com/2012/11/a-wordcloud-in-python.html

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(tweets_df['absolute_tidy_tweets'])

# %%
show_wordcloud(neg_tweets)

# %% [markdown]
# # Topic Modeling
# - https://www.aclweb.org/anthology/W17-0210

# %%
def topic_model_lda(processed_corpus, num_topics=5, num_words=4):
    '''
    Uses Latent Dirichlect Allocation for topic modeling
    Borrowed from https://towardsdatascience.com/topic-modelling-in-python-with-nltk-and-gensim-4ef03213cd21
    
    Inputs: 
        - Processed_corpus: The corpus of text that has already been tokenized/stemmed/etc.
        - num_topics: The number of topics to discover in the text
        - num_words: The number of words per topic to print in the output
    
    Outputs: 
        - A pretty printed list of words in each topic and the probability associated with them
        - A dataframe with the topics assigned to each sample
    
    TODO: Print interpretation of the numbers
    '''
    import gensim
    
    # Additional processing before modeling
    dictionary = gensim.corpora.Dictionary(processed_corpus)
    corpus = [dictionary.doc2bow(text) for text in processed_corpus]
    
    # Performing LDA
    lda_model = gensim.models.ldamodel.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=15)
    topics = lda_model.print_topics(num_words=num_words)
    
    ## Assigning the topics to individual comments
    results = pd.DataFrame(processed_corpus)  # Putting the series into a dataframe
    
    # Calculating the probability of each topic and assigning the topic with the highest probability
    results['Topic'] = processed_corpus.apply(lambda sentence: np.matrix(lda_model[dictionary.doc2bow(sentence)])[:, 1].argmax())
    
    # Calculating the total number of phrases in each topic
    number_phrases_per_topic = results['Topic'].value_counts()
    
    # Reporting the topics
    for topic in topics:
        print('Topic {0} ({1} samples):'.format(topic[0], number_phrases_per_topic.loc[topic[0]]))  # Printing the topic number
        topic_words = topic[-1].replace('"', '').replace(' ', '')  # Removing white space and quotes
        topic_words = [word.split('*') for word in topic_words.split('+')]  # Splitting into one item for the word and one for the probability
        [print(' {0}: {1}'.format(x[1], x[0])) for x in topic_words]  # Printing the results as word: probability
        print()  # New line
    
    return results

# %%
import spacy
# spacy.load('en')
from spacy.lang.en import English
parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Sam
# [nltk_data]     Cannon\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
